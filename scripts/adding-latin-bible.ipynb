# %%
import pandas as pd

# %%
grela_metadata = pd.read_parquet("../data/grela_works_metadata.parquet")

# %%
grela_metadata[grela_metadata["title"].str.contains("Bibl", na=False)]
# Out:
#       grela_source             grela_id  \
# 1679          lagt  lagt_tlg1765.tlg006
# 2024          lagt  lagt_tlg2959.tlg005
# 4653            cc             cc_13200
# 5828            cc             cc_17102
# 5829            cc             cc_17103
# 5830            cc             cc_17104
# 6572            cc             cc_21332
# 6996            cc              cc_7032
# 7185            cc              cc_7219
# 8956            cc              cc_8973
# 10013     noscemus      noscemus_718447
# 10086     noscemus      noscemus_653294
# 10124     noscemus      noscemus_630005
# 10198     noscemus      noscemus_746791
# 10199     noscemus      noscemus_630006
# 10254     noscemus      noscemus_770048
# 10255     noscemus      noscemus_770049
# 10357     noscemus      noscemus_704336
# 10358     noscemus      noscemus_704338
# 10401     noscemus      noscemus_929707
# 10553     noscemus      noscemus_704339
# 10572     noscemus      noscemus_653298
# ...
